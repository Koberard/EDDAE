# %%
import h5py
import numpy as np
import os
import matplotlib.pyplot as plt
import os
import tensorflow as tf
# Out:
# 2026-03-10 15:22:52.360972: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773181372.377467 2046197 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773181372.382841 2046197 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773181372.397343 2046197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773181372.397358 2046197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773181372.397360 2046197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773181372.397362 2046197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-10 15:22:52.401682: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("here")
# Out:
# here

# %%
# minorized reference
with h5py.File('/pscratch/sd/k/kberard/SCGSR/Data/bp_1x1x1_ccecp/density_data/vmc_J2/density_tot_ref_mean.h5', 'r') as file:
    #print("Keys: %s" % file.keys())
    ref_d = file['density'][:]
#print(ref_d)
print(ref_d.shape)
# Out:
# (140, 84, 112)

# %%
def D_JS(p1,p2,tol=1e-16):
    p1=p1/np.sum(p1)
    p2=p2/np.sum(p2)
    pm = (p1+p2)/2
    p1_nonzero = np.abs(p1)>tol
    p2_nonzero = np.abs(p2)>tol
    p1  = np.abs(p1[p1_nonzero])
    pm1 = np.abs(pm[p1_nonzero])
    p2  = np.abs(p2[p2_nonzero])
    pm2 = np.abs(pm[p2_nonzero])
    d = .5*( (p1*np.log(p1/pm1)).sum() + (p2*np.log(p2/pm2)).sum() )
    d /= np.log(2) # normalize to max of 1
    return d

# %%
data = np.load("/pscratch/sd/k/kberard/SCGSR/EDDA/BP/Data_Gen/DFT_Blobs_Fixed/DFT_dat_lev_24612461000000_samples_Residual_Perturbed.npz")

# %%
x_train = data['x_train']
x_val   = data['x_val']
y_train = data['y_train']
y_val   = data['y_val']
n_samples = data["total_samples"]

x_train = x_train[..., np.newaxis]
x_val   = x_val[..., np.newaxis]

y_train = y_train[..., np.newaxis]
y_val   = y_val[..., np.newaxis]
data = 0

# %%
dft_path ='/pscratch/sd/k/kberard/SCGSR/Data/bp_1x1x1_ccecp/density_data/vmc_noJ/density_tot_ref.h5'
with h5py.File(dft_path, 'r') as file:
    dft_d = file['density'][:]
# 1. Get the residual map (what the network sees)
residual_map = x_train[0,:,:,:,0]
print(f"Residual Sum: {np.sum(residual_map):.2f} (Expected: close to 0, not 50)")

# 2. Inverse Transform to get Real Density
# Formula: Density = (Residual * sqrt(DFT)) + DFT
epsilon = 1e-9
dsqrt = np.sqrt(np.abs(dft_d) + epsilon)
restored_density = (residual_map * dsqrt) + dft_d

# 3. Check the Sum
total_electrons = np.sum(restored_density)
print(f"Total Electrons: {total_electrons:.4f} (Expected: ~8.0)")
# Out:
# Residual Sum: 0.13 (Expected: close to 0, not 50)
# Total Electrons: 19.9993 (Expected: ~8.0)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks

def create_residual_unet(input_shape):
    inputs = layers.Input(shape=input_shape)
    
    # Standard U-Net (Depth 2 is fine for residuals)
    # Encoder
    c1 = layers.Conv3D(32, 3, padding='same', activation='relu')(inputs)
    c1 = layers.Conv3D(32, 3, padding='same', activation='relu')(c1)
    p1 = layers.MaxPooling3D(2)(c1)
    
    c2 = layers.Conv3D(64, 3, padding='same', activation='relu')(p1)
    c2 = layers.Conv3D(64, 3, padding='same', activation='relu')(c2)
    p2 = layers.MaxPooling3D(2)(c2)
    
    # Bottleneck
    b = layers.Conv3D(128, 3, padding='same', activation='relu')(p2)
    b = layers.Conv3D(128, 3, padding='same', activation='relu')(b)
    
    # Decoder
    u1 = layers.UpSampling3D(2)(b)
    u1 = layers.Concatenate()([u1, c2])
    d1 = layers.Conv3D(64, 3, padding='same', activation='relu')(u1)
    d1 = layers.Conv3D(64, 3, padding='same', activation='relu')(d1)
    
    u2 = layers.UpSampling3D(2)(d1)
    u2 = layers.Concatenate()([u2, c1])
    d2 = layers.Conv3D(32, 3, padding='same', activation='relu')(u2)
    d2 = layers.Conv3D(32, 3, padding='same', activation='relu')(d2)
    
    # Output: predicting the RESIDUAL, can be negative, so LINEAR activation
    outputs = layers.Conv3D(1, 1, padding='same', activation='linear')(d2)
    
    return models.Model(inputs, outputs)

# Compile & Train
model = create_residual_unet(x_train.shape[1:])
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss='mse') 

model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    batch_size=8,
    epochs=50,
    callbacks=[
        callbacks.EarlyStopping(patience=10, restore_best_weights=True),
        callbacks.ReduceLROnPlateau(patience=5, factor=0.5)
    ]
)
model.save("residual_denoiser_40M_Blob_Fixed_trans.keras")
# Out:
# I0000 00:00:1773181438.583725 2046197 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38479 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773181448.127275 2046355 service.cc:152] XLA service 0x7f9510213740 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1773181448.127303 2046355 service.cc:160]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2026-03-10 15:24:08.189687: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1773181448.720657 2046355 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2026-03-10 15:24:11.342343: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.34 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.4980, f32[32]{0} %bitcast.5039), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_1_2/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:12.206710: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.864460719s
# Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.34 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.4980, f32[32]{0} %bitcast.5039), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_1_2/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:18.773454: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.41 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.5723, f32[32]{0} %bitcast.5782), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_8_1/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:23.383632: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 5.61025672s
# Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.41 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.5723, f32[32]{0} %bitcast.5782), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_8_1/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:25.255545: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-10 15:24:25.432900: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-10 15:24:27.295189: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-input.9 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5891, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.5829), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_9_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:27.562415: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.267305453s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-input.9 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5891, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.5829), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_9_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:28.535323: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-10 15:24:28.773427: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-10 15:24:32.858877: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-input.10 = (f32[8,96,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.5723), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:35.635820: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 3.777011878s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-input.10 = (f32[8,96,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.5723), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:39.163461: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-input.12 = (f32[8,192,70,42,56]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5575, f32[64,192,3,3,3]{4,3,2,1,0} %bitcast.5512), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_6_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:40.044712: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.881339154s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-input.12 = (f32[8,192,70,42,56]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5575, f32[64,192,3,3,3]{4,3,2,1,0} %bitcast.5512), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_6_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773181482.186901 2046355 buffer_comparator.cc:156] Difference at 0: 2.57398e+06, expected 2.27203e+06
# E0000 00:00:1773181482.186933 2046355 buffer_comparator.cc:156] Difference at 1: 2.59876e+06, expected 2.29023e+06
# E0000 00:00:1773181482.186937 2046355 buffer_comparator.cc:156] Difference at 2: 2.57287e+06, expected 2.27012e+06
# E0000 00:00:1773181482.186940 2046355 buffer_comparator.cc:156] Difference at 3: 2.60688e+06, expected 2.29506e+06
# E0000 00:00:1773181482.186943 2046355 buffer_comparator.cc:156] Difference at 4: 2.62667e+06, expected 2.31083e+06
# E0000 00:00:1773181482.186945 2046355 buffer_comparator.cc:156] Difference at 5: 2.61028e+06, expected 2.29907e+06
# E0000 00:00:1773181482.186948 2046355 buffer_comparator.cc:156] Difference at 6: 2.57966e+06, expected 2.27717e+06
# E0000 00:00:1773181482.186951 2046355 buffer_comparator.cc:156] Difference at 7: 2.60117e+06, expected 2.29246e+06
# E0000 00:00:1773181482.186954 2046355 buffer_comparator.cc:156] Difference at 8: 2.56918e+06, expected 2.2692e+06
# E0000 00:00:1773181482.186957 2046355 buffer_comparator.cc:156] Difference at 9: 2.59744e+06, expected 2.28985e+06
# 2026-03-10 15:24:42.186970: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.11 = (f32[32,1,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.4520, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4937), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=0,k12=54,k13=2,k14=3,k15=1,k17=55,k18=1,k23=0} vs eng23{k2=8,k13=1,k14=4,k18=1,k23=0}
# 2026-03-10 15:24:42.186982: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-10 15:24:42.186986: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-10 15:24:42.186989: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-10 15:24:42.186991: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-10 15:24:42.186996: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# E0000 00:00:1773181482.858427 2046355 buffer_comparator.cc:156] Difference at 0: 2.57398e+06, expected 2.27203e+06
# E0000 00:00:1773181482.858446 2046355 buffer_comparator.cc:156] Difference at 1: 2.59876e+06, expected 2.29023e+06
# E0000 00:00:1773181482.858450 2046355 buffer_comparator.cc:156] Difference at 2: 2.57287e+06, expected 2.27012e+06
# E0000 00:00:1773181482.858452 2046355 buffer_comparator.cc:156] Difference at 3: 2.60688e+06, expected 2.29506e+06
# E0000 00:00:1773181482.858455 2046355 buffer_comparator.cc:156] Difference at 4: 2.62667e+06, expected 2.31083e+06
# E0000 00:00:1773181482.858458 2046355 buffer_comparator.cc:156] Difference at 5: 2.61028e+06, expected 2.29907e+06
# E0000 00:00:1773181482.858460 2046355 buffer_comparator.cc:156] Difference at 6: 2.57966e+06, expected 2.27717e+06
# E0000 00:00:1773181482.858463 2046355 buffer_comparator.cc:156] Difference at 7: 2.60117e+06, expected 2.29246e+06
# E0000 00:00:1773181482.858465 2046355 buffer_comparator.cc:156] Difference at 8: 2.56918e+06, expected 2.2692e+06
# E0000 00:00:1773181482.858468 2046355 buffer_comparator.cc:156] Difference at 9: 2.59744e+06, expected 2.28985e+06
# 2026-03-10 15:24:42.858478: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.11 = (f32[32,1,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.4520, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4937), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=0,k12=54,k13=2,k14=3,k15=1,k17=55,k18=1,k23=0} vs eng23{k2=5,k13=1,k14=3,k18=1,k23=0}
# 2026-03-10 15:24:42.858485: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-10 15:24:42.858488: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-10 15:24:42.858490: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-10 15:24:42.858493: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-10 15:24:42.858496: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-10 15:24:46.124184: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.11 = (f32[32,1,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.4520, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4937), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773181487.571794 2046355 buffer_comparator.cc:156] Difference at 0: 2.57398e+06, expected 2.27203e+06
# E0000 00:00:1773181487.571827 2046355 buffer_comparator.cc:156] Difference at 1: 2.59876e+06, expected 2.29023e+06
# E0000 00:00:1773181487.571830 2046355 buffer_comparator.cc:156] Difference at 2: 2.57287e+06, expected 2.27012e+06
# E0000 00:00:1773181487.571833 2046355 buffer_comparator.cc:156] Difference at 3: 2.60688e+06, expected 2.29506e+06
# E0000 00:00:1773181487.571836 2046355 buffer_comparator.cc:156] Difference at 4: 2.62667e+06, expected 2.31083e+06
# E0000 00:00:1773181487.571839 2046355 buffer_comparator.cc:156] Difference at 5: 2.61028e+06, expected 2.29907e+06
# E0000 00:00:1773181487.571841 2046355 buffer_comparator.cc:156] Difference at 6: 2.57966e+06, expected 2.27717e+06
# E0000 00:00:1773181487.571844 2046355 buffer_comparator.cc:156] Difference at 7: 2.60117e+06, expected 2.29246e+06
# E0000 00:00:1773181487.571846 2046355 buffer_comparator.cc:156] Difference at 8: 2.56918e+06, expected 2.2692e+06
# E0000 00:00:1773181487.571849 2046355 buffer_comparator.cc:156] Difference at 9: 2.59744e+06, expected 2.28985e+06
# 2026-03-10 15:24:47.571861: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.11 = (f32[32,1,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.4520, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4937), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=0,k12=54,k13=2,k14=3,k15=1,k17=55,k18=1,k23=0} vs eng23{k2=6,k13=0,k14=2,k18=1,k23=0}
# 2026-03-10 15:24:47.571873: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-10 15:24:47.571876: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-10 15:24:47.571880: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-10 15:24:47.571882: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-10 15:24:47.571886: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-10 15:24:47.571894: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.447788998s
# Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.11 = (f32[32,1,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.4520, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4937), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773181488.503699 2046355 buffer_comparator.cc:156] Difference at 0: 2.53402e+06, expected 2.27141e+06
# E0000 00:00:1773181488.503727 2046355 buffer_comparator.cc:156] Difference at 1: 2.56405e+06, expected 2.29326e+06
# E0000 00:00:1773181488.503731 2046355 buffer_comparator.cc:156] Difference at 2: 2.53728e+06, expected 2.27383e+06
# E0000 00:00:1773181488.503734 2046355 buffer_comparator.cc:156] Difference at 3: 2.57423e+06, expected 2.30145e+06
# E0000 00:00:1773181488.503738 2046355 buffer_comparator.cc:156] Difference at 4: 2.58744e+06, expected 2.31134e+06
# E0000 00:00:1773181488.503741 2046355 buffer_comparator.cc:156] Difference at 5: 2.57304e+06, expected 2.29988e+06
# E0000 00:00:1773181488.503744 2046355 buffer_comparator.cc:156] Difference at 6: 2.54073e+06, expected 2.2749e+06
# E0000 00:00:1773181488.503747 2046355 buffer_comparator.cc:156] Difference at 7: 2.54695e+06, expected 2.28108e+06
# E0000 00:00:1773181488.503750 2046355 buffer_comparator.cc:156] Difference at 8: 2.52413e+06, expected 2.26228e+06
# E0000 00:00:1773181488.503753 2046355 buffer_comparator.cc:156] Difference at 9: 2.559e+06, expected 2.29096e+06
# 2026-03-10 15:24:48.503767: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=7,k12=7,k13=0,k14=4,k15=1,k17=8,k18=1,k23=0} vs eng23{k2=8,k13=1,k14=4,k18=1,k23=0}
# 2026-03-10 15:24:48.503785: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-10 15:24:48.503788: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-10 15:24:48.503792: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-10 15:24:48.503795: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-10 15:24:48.503799: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# E0000 00:00:1773181488.982459 2046355 buffer_comparator.cc:156] Difference at 0: 2.53402e+06, expected 2.27141e+06
# E0000 00:00:1773181488.982472 2046355 buffer_comparator.cc:156] Difference at 1: 2.56405e+06, expected 2.29326e+06
# E0000 00:00:1773181488.982476 2046355 buffer_comparator.cc:156] Difference at 2: 2.53728e+06, expected 2.27383e+06
# E0000 00:00:1773181488.982478 2046355 buffer_comparator.cc:156] Difference at 3: 2.57423e+06, expected 2.30145e+06
# E0000 00:00:1773181488.982481 2046355 buffer_comparator.cc:156] Difference at 4: 2.58744e+06, expected 2.31134e+06
# E0000 00:00:1773181488.982484 2046355 buffer_comparator.cc:156] Difference at 5: 2.57304e+06, expected 2.29988e+06
# E0000 00:00:1773181488.982486 2046355 buffer_comparator.cc:156] Difference at 6: 2.54073e+06, expected 2.2749e+06
# E0000 00:00:1773181488.982489 2046355 buffer_comparator.cc:156] Difference at 7: 2.54695e+06, expected 2.28108e+06
# E0000 00:00:1773181488.982492 2046355 buffer_comparator.cc:156] Difference at 8: 2.52413e+06, expected 2.26228e+06
# E0000 00:00:1773181488.982495 2046355 buffer_comparator.cc:156] Difference at 9: 2.559e+06, expected 2.29096e+06
# 2026-03-10 15:24:48.982503: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=7,k12=7,k13=0,k14=4,k15=1,k17=8,k18=1,k23=0} vs eng23{k2=5,k13=1,k14=3,k18=1,k23=0}
# 2026-03-10 15:24:48.982510: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-10 15:24:48.982513: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-10 15:24:48.982515: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-10 15:24:48.982517: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-10 15:24:48.982521: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-10 15:24:51.656434: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng20{k2=3,k3=0} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:51.817372: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.161016353s
# Trying algorithm eng20{k2=3,k3=0} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:52.817497: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773181493.890815 2046355 buffer_comparator.cc:156] Difference at 0: 2.53402e+06, expected 2.27141e+06
# E0000 00:00:1773181493.890838 2046355 buffer_comparator.cc:156] Difference at 1: 2.56405e+06, expected 2.29326e+06
# E0000 00:00:1773181493.890842 2046355 buffer_comparator.cc:156] Difference at 2: 2.53728e+06, expected 2.27383e+06
# E0000 00:00:1773181493.890844 2046355 buffer_comparator.cc:156] Difference at 3: 2.57423e+06, expected 2.30145e+06
# E0000 00:00:1773181493.890847 2046355 buffer_comparator.cc:156] Difference at 4: 2.58744e+06, expected 2.31134e+06
# E0000 00:00:1773181493.890850 2046355 buffer_comparator.cc:156] Difference at 5: 2.57304e+06, expected 2.29988e+06
# E0000 00:00:1773181493.890852 2046355 buffer_comparator.cc:156] Difference at 6: 2.54073e+06, expected 2.2749e+06
# E0000 00:00:1773181493.890855 2046355 buffer_comparator.cc:156] Difference at 7: 2.54695e+06, expected 2.28108e+06
# E0000 00:00:1773181493.890858 2046355 buffer_comparator.cc:156] Difference at 8: 2.52413e+06, expected 2.26228e+06
# E0000 00:00:1773181493.890860 2046355 buffer_comparator.cc:156] Difference at 9: 2.559e+06, expected 2.29096e+06
# 2026-03-10 15:24:53.890871: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=7,k12=7,k13=0,k14=4,k15=1,k17=8,k18=1,k23=0} vs eng23{k2=6,k13=0,k14=2,k18=1,k23=0}
# 2026-03-10 15:24:53.890880: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-10 15:24:53.890883: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-10 15:24:53.890886: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-10 15:24:53.890888: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-10 15:24:53.890893: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-10 15:24:53.890900: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.073491861s
# Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:54.891016: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:24:56.900071: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 3.009134646s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:00.847503: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.14 = (f32[64,64,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5202, f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5256), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_3_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:01.273864: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.426447284s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.14 = (f32[64,64,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5202, f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5256), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_3_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:05.810710: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.17 = (f32[64,192,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,192,70,42,56]{4,3,2,1,0} %bitcast.5521, f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5575), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_6_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:09.058264: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 4.247624805s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.17 = (f32[64,192,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,192,70,42,56]{4,3,2,1,0} %bitcast.5521, f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5575), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_6_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:12.678529: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng20{k2=7,k3=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:12.734750: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.056287546s
# Trying algorithm eng20{k2=7,k3=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:14.602431: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng20{k2=3,k3=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:15.704535: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.102172706s
# Trying algorithm eng20{k2=3,k3=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:16.704661: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:17.790587: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.085996328s
# Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:18.790698: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:25:26.524108: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 8.733467176s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773181528.311858 2046355 buffer_comparator.cc:156] Difference at 0: 2.65755e+06, expected 2.3267e+06
# E0000 00:00:1773181528.311899 2046355 buffer_comparator.cc:156] Difference at 1: 2.6595e+06, expected 2.33052e+06
# E0000 00:00:1773181528.311903 2046355 buffer_comparator.cc:156] Difference at 2: 2.65214e+06, expected 2.32367e+06
# E0000 00:00:1773181528.311906 2046355 buffer_comparator.cc:156] Difference at 3: 2.6581e+06, expected 2.32852e+06
# E0000 00:00:1773181528.311908 2046355 buffer_comparator.cc:156] Difference at 4: 2.65554e+06, expected 2.32582e+06
# ...
# 2026-03-10 15:25:32.116256: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-10 15:25:32.116259: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-10 15:25:32.116261: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-10 15:25:32.116264: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-10 15:25:32.116268: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-10 15:25:33.116370: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.21 = (f32[1,32,1,1,1]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5940, f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.5942), window={size=1x1x1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_10_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773181534.185410 2046355 buffer_comparator.cc:156] Difference at 0: 2.65755e+06, expected 2.3267e+06
# E0000 00:00:1773181534.185435 2046355 buffer_comparator.cc:156] Difference at 1: 2.6595e+06, expected 2.33052e+06
# E0000 00:00:1773181534.185439 2046355 buffer_comparator.cc:156] Difference at 2: 2.65214e+06, expected 2.32367e+06
# E0000 00:00:1773181534.185442 2046355 buffer_comparator.cc:156] Difference at 3: 2.6581e+06, expected 2.32852e+06
# E0000 00:00:1773181534.185445 2046355 buffer_comparator.cc:156] Difference at 4: 2.65554e+06, expected 2.32582e+06
# E0000 00:00:1773181534.185448 2046355 buffer_comparator.cc:156] Difference at 5: 2.65227e+06, expected 2.32594e+06
# E0000 00:00:1773181534.185451 2046355 buffer_comparator.cc:156] Difference at 6: 2.65491e+06, expected 2.32607e+06
# E0000 00:00:1773181534.185454 2046355 buffer_comparator.cc:156] Difference at 7: 2.65529e+06, expected 2.32726e+06
# E0000 00:00:1773181534.185457 2046355 buffer_comparator.cc:156] Difference at 8: 2.65657e+06, expected 2.32894e+06
# E0000 00:00:1773181534.185460 2046355 buffer_comparator.cc:156] Difference at 9: 2.65861e+06, expected 2.32897e+06
# 2026-03-10 15:25:34.185471: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.21 = (f32[1,32,1,1,1]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5940, f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.5942), window={size=1x1x1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_10_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng62{k25=2} vs eng23{k2=6,k13=0,k14=2,k18=1,k23=0}
# 2026-03-10 15:25:34.185480: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-10 15:25:34.185483: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-10 15:25:34.185486: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-10 15:25:34.185489: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-10 15:25:34.185494: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-10 15:25:34.185506: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.069199191s
# Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.21 = (f32[1,32,1,1,1]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5940, f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.5942), window={size=1x1x1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_10_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# I0000 00:00:1773181536.354444 2046355 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - loss: 8.0396e-09
# 2026-03-10 15:26:28.050832: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.34 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.498, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.505, f32[32]{0} %bitcast.507), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_1_2/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:26:28.914858: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.864108349s
# Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.34 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.498, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.505, f32[32]{0} %bitcast.507), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_1_2/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:26:35.481392: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.41 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.619, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.626, f32[32]{0} %bitcast.628), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_8_1/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-10 15:26:40.092320: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 5.611001882s
# Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.41 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.619, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.626, f32[32]{0} %bitcast.628), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_8_1/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 157s 534ms/step - loss: 7.9927e-09 - val_loss: 1.2594e-10 - learning_rate: 1.0000e-04
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 1.1350e-10 - val_loss: 1.0598e-10 - learning_rate: 1.0000e-04
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 9.9301e-11 - val_loss: 9.4906e-11 - learning_rate: 1.0000e-04
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 8.4589e-11 - val_loss: 8.7738e-11 - learning_rate: 1.0000e-04
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 8.1607e-11 - val_loss: 8.3740e-11 - learning_rate: 1.0000e-04
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 7.7928e-11 - val_loss: 8.0490e-11 - learning_rate: 1.0000e-04
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 7.4656e-11 - val_loss: 7.9334e-11 - learning_rate: 5.0000e-05
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 7.3345e-11 - val_loss: 7.8194e-11 - learning_rate: 5.0000e-05
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 7.2990e-11 - val_loss: 7.6607e-11 - learning_rate: 5.0000e-05
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 7.1350e-11 - val_loss: 7.4799e-11 - learning_rate: 5.0000e-05
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 7.0867e-11 - val_loss: 7.3789e-11 - learning_rate: 5.0000e-05
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.9440e-11 - val_loss: 7.3467e-11 - learning_rate: 2.5000e-05
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.9114e-11 - val_loss: 7.3199e-11 - learning_rate: 2.5000e-05
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.7761e-11 - val_loss: 7.2968e-11 - learning_rate: 2.5000e-05
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.8273e-11 - val_loss: 7.2767e-11 - learning_rate: 2.5000e-05
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.8865e-11 - val_loss: 7.2582e-11 - learning_rate: 2.5000e-05
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.9289e-11 - val_loss: 7.2496e-11 - learning_rate: 1.2500e-05
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.7727e-11 - val_loss: 7.2411e-11 - learning_rate: 1.2500e-05
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.7247e-11 - val_loss: 7.2328e-11 - learning_rate: 1.2500e-05
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.7472e-11 - val_loss: 7.2250e-11 - learning_rate: 1.2500e-05
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.8147e-11 - val_loss: 7.2169e-11 - learning_rate: 1.2500e-05
# Epoch 22/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.7841e-11 - val_loss: 7.2131e-11 - learning_rate: 6.2500e-06
# Epoch 23/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.6486e-11 - val_loss: 7.2092e-11 - learning_rate: 6.2500e-06
# Epoch 24/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.7362e-11 - val_loss: 7.2053e-11 - learning_rate: 6.2500e-06
# Epoch 25/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.6270e-11 - val_loss: 7.2015e-11 - learning_rate: 6.2500e-06
# Epoch 26/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.6141e-11 - val_loss: 7.1976e-11 - learning_rate: 6.2500e-06
# Epoch 27/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.9210e-11 - val_loss: 7.1957e-11 - learning_rate: 3.1250e-06
# Epoch 28/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.8478e-11 - val_loss: 7.1937e-11 - learning_rate: 3.1250e-06
# Epoch 29/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.7060e-11 - val_loss: 7.1917e-11 - learning_rate: 3.1250e-06
# Epoch 30/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.6420e-11 - val_loss: 7.1897e-11 - learning_rate: 3.1250e-06
# Epoch 31/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.8131e-11 - val_loss: 7.1876e-11 - learning_rate: 3.1250e-06
# Epoch 32/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.9085e-11 - val_loss: 7.1866e-11 - learning_rate: 1.5625e-06
# Epoch 33/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.7297e-11 - val_loss: 7.1855e-11 - learning_rate: 1.5625e-06
# Epoch 34/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.6406e-11 - val_loss: 7.1844e-11 - learning_rate: 1.5625e-06
# Epoch 35/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.6947e-11 - val_loss: 7.1833e-11 - learning_rate: 1.5625e-06
# Epoch 36/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.8436e-11 - val_loss: 7.1821e-11 - learning_rate: 1.5625e-06
# Epoch 37/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.6559e-11 - val_loss: 7.1815e-11 - learning_rate: 7.8125e-07
# Epoch 38/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.5744e-11 - val_loss: 7.1809e-11 - learning_rate: 7.8125e-07
# Epoch 39/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.5765e-11 - val_loss: 7.1803e-11 - learning_rate: 7.8125e-07
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.6459e-11 - val_loss: 7.1797e-11 - learning_rate: 7.8125e-07
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.5517e-11 - val_loss: 7.1791e-11 - learning_rate: 7.8125e-07
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.7407e-11 - val_loss: 7.1788e-11 - learning_rate: 3.9062e-07
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.6627e-11 - val_loss: 7.1784e-11 - learning_rate: 3.9062e-07
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.5033e-11 - val_loss: 7.1781e-11 - learning_rate: 3.9062e-07
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.6634e-11 - val_loss: 7.1778e-11 - learning_rate: 3.9062e-07
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - loss: 6.6443e-11 - val_loss: 7.1774e-11 - learning_rate: 3.9062e-07
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.6713e-11 - val_loss: 7.1772e-11 - learning_rate: 1.9531e-07
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.7415e-11 - val_loss: 7.1771e-11 - learning_rate: 1.9531e-07
# Epoch 49/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.6790e-11 - val_loss: 7.1769e-11 - learning_rate: 1.9531e-07
# Epoch 50/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 6.7225e-11 - val_loss: 7.1767e-11 - learning_rate: 1.9531e-07

# %%
with h5py.File('/pscratch/sd/k/kberard/SCGSR/Data/bp_1x1x1_ccecp/density_data/vmc_J2/density_tot_vmc_mean_0006881280.h5', 'r') as file:
    #print("Keys: %s" % file.keys())
    test_d = file['density'][:]

# %%
#Transform density
def transform(density,density_ref,transform_type):
    dens = density
    dref  = density_ref
    ttype = transform_type
    if ttype=='value':
        dtrans = density
    elif ttype=='sqrt':
        dtrans = np.sqrt(np.abs(density))
    elif ttype=='log':
        dtrans  = np.log(np.abs(density))
    elif ttype=='residual_noise':
        dval  = dref
        dsqrt = np.sqrt(np.abs(dref))
        dtrans = (dens-dval)/dsqrt
    else:
        raise RuntimeError('bad transform type')
    return dtrans


def inverse_transform(density_trans,density_ref,transform_type):
    dref   = density_ref
    ttype  = transform_type
    dtrans = density_trans
    if ttype=='value':
        density = dtrans
    elif ttype=='sqrt':
        density = dtrans**2
    elif ttype=='log':
        density = np.log(np.abs(dtrans))
    elif ttype=='residual_noise':
        dval  = dref
        dsqrt = np.sqrt(np.abs(dref))
        density = dval + dsqrt*dtrans
    else:
        raise RuntimeError('bad transform type')
    return density

# %%
import os
import glob
import h5py
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import re
dft_path ='/pscratch/sd/k/kberard/SCGSR/Data/bp_1x1x1_ccecp/density_data/vmc_noJ/density_tot_ref.h5'
with h5py.File(dft_path, 'r') as file:
    dft_d = file['density'][:]

# %%
import numpy as np
import matplotlib.pyplot as plt
model = tf.keras.models.load_model('residual_denoiser_40M_Blob_Fixed_trans.keras')
# -----------------------------------------------------------
# 1. PREPARE DATA FOR MODEL
# -----------------------------------------------------------
# Reshape arrays to (1, H, W, D, 1) for the model
# We need 'dft_d' because the residual transform relies on it.
input_reshaped = test_d[np.newaxis, ..., np.newaxis]
dft_reshaped   = dft_d[np.newaxis, ..., np.newaxis]

# -----------------------------------------------------------
# 2. TRANSFORM INPUT (Forward Pass)
# -----------------------------------------------------------
# Convert raw noisy density -> "How far is this from DFT?"
# Uses the 'transform' function we defined earlier
input_residual = transform(input_reshaped, dft_reshaped, 'residual_noise')

# -----------------------------------------------------------
# 3. PREDICT
# -----------------------------------------------------------
# The model predicts the "Corrected Residual"
pred_residual = model.predict(input_residual)

# -----------------------------------------------------------
# 4. INVERSE TRANSFORM (Recover Density)
# -----------------------------------------------------------
# Convert "Corrected Residual" back to "Physical Density"
# Logic: Density = DFT + (Residual * sqrt(DFT))
denoised_raw = inverse_transform(pred_residual, dft_reshaped, 'residual_noise')

# Squeeze back to 3D shape (116, 116, 72)
denoised = denoised_raw[0, ..., 0]

# Safety: Density cannot be negative (physics constraint)
denoised = np.maximum(denoised, 0.0)

# -----------------------------------------------------------
# 5. VISUALIZATION & METRICS (Your snippet)
# -----------------------------------------------------------
noisy_input = test_d
true_clean = ref_d

# Dynamic z-slice (don't hardcode 64 if depth is 72)
z_mid = noisy_input.shape[2] // 2

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(noisy_input[:, :, z_mid], cmap='viridis')
plt.title("Noisy Input")
plt.colorbar()

plt.subplot(1, 3, 2)
plt.imshow(denoised[:, :, z_mid], cmap='viridis')
plt.title("Denoised Output\n(Residual Reconstructed)")
plt.colorbar()

plt.subplot(1, 3, 3)
plt.imshow(true_clean[:, :, z_mid], cmap='viridis')
plt.title("Reference (Ground Truth)")
plt.colorbar()

plt.tight_layout()
plt.show()

# Metric Calculation
# Ensure JSD handles small epsilons
print("JSD between noisy and Ref:", D_JS(test_d, ref_d, tol=1e-16))
print("JSD between denoised and Ref:", D_JS(denoised, ref_d, tol=1e-16))
print("JSD between denoised and DFT:", D_JS(denoised, dft_d, tol=1e-16))
print("JSD between noise and DFT:", D_JS(test_d, dft_d, tol=1e-16))
print("JSD between Ref and DFT:", D_JS(ref_d, dft_d, tol=1e-16))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# JSD between noisy and Ref: 0.0019013732494608747
# JSD between denoised and Ref: 0.00018216939314267354
# JSD between denoised and DFT: 4.249387574402213e-08
# JSD between noise and DFT: 0.002071016207691635
# JSD between Ref and DFT: 0.00018184807341338878

# %%
print("here")
# Out:
# here

# %%
# --- Setup Directory Looping ---
model = tf.keras.models.load_model('residual_denoiser_40M_Blob_Fixed_trans.keras')
data_dir = '/pscratch/sd/k/kberard/SCGSR/Data/bp_1x1x1_ccecp/density_data/vmc_J2/'
file_pattern = os.path.join(data_dir, "density_tot_vmc_mean_*.h5")
files = glob.glob(file_pattern)

results = []

# --- Processing Loop ---
for fpath in files:
    # Extract number of samples from filename using regex
    match = re.search(r'mean_(\d+)\.h5', os.path.basename(fpath))
    if not match: continue
    sample_count = int(match.group(1))
    
    with h5py.File(fpath, 'r') as f:
        test_d = np.array(f['density'])
    
    # 1. Transform & Predict
    input_reshaped = test_d[np.newaxis, ..., np.newaxis]
    dft_reshaped   = dft_d[np.newaxis, ..., np.newaxis]
    input_residual = transform(input_reshaped, dft_reshaped, 'residual_noise')
    
    pred_residual = model.predict(input_residual, verbose=0)
    
    # 2. Inverse Transform
    denoised_raw = inverse_transform(pred_residual, dft_reshaped, 'residual_noise')
    denoised = np.maximum(denoised_raw[0, ..., 0], 0.0)

    # 3. Store Metrics
    jsd_noisy = D_JS(test_d, ref_d)
    jsd_denoised = D_JS(denoised, ref_d)
    
    results.append((sample_count, jsd_noisy, jsd_denoised))

# --- Sorting & Plotting ---
# Sort results by sample count (x-axis)
results.sort(key=lambda x: x[0])
samples, noisy_jsds, denoised_jsds = zip(*results)

# %%
DFT_vs_DMC = D_JS(ref_d,dft_d)
plt.figure(figsize=(10, 6))
plt.plot(samples, noisy_jsds, 'r--o', label='Noisy vs Reference', alpha=0.6)
plt.plot(samples, denoised_jsds, 'g-s', label='Denoised vs Reference', linewidth=2)

plt.xscale('log') # Sample counts usually span orders of magnitude
plt.yscale('log') # JSD values often drop significantly
plt.axhline(DFT_vs_DMC, color="black", linestyle=":", label="DFT vs DMC")
plt.xlabel('Number of Samples (VMC)')
plt.ylabel('$D_{JS}$ (Jensen-Shannon Divergence)')
plt.title('Denoising Error Reduction vs. Sample Count')
plt.legend()
plt.grid(True, which="both", ls="-", alpha=0.2)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Create a DataFrame with your data
data = {
    'Samples': samples,
    'Noisy_JSD': noisy_jsds,
    'Denoised_JSD': denoised_jsds
}
df = pd.DataFrame(data)

# Save to CSV
df.to_csv('diamond_jsd_data.csv', index=False)
print("Data saved to bp_fixed_jsd_data.csv")
# Out:
# Data saved to bp_fixed_jsd_data.csv
