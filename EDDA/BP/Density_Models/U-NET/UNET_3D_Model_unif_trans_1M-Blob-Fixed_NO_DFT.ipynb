# %%
import h5py
import numpy as np
import os
import matplotlib.pyplot as plt
import os
import tensorflow as tf
# Out:
# 2026-03-10 16:37:31.112211: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773185851.127932 2071203 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773185851.133029 2071203 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773185851.147410 2071203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773185851.147424 2071203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773185851.147426 2071203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773185851.147428 2071203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-10 16:37:31.151714: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("here")
# Out:
# here

# %%
def D_JS(p1,p2,tol=1e-16):
    p1=p1/np.sum(p1)
    p2=p2/np.sum(p2)
    pm = (p1+p2)/2
    p1_nonzero = np.abs(p1)>tol
    p2_nonzero = np.abs(p2)>tol
    p1  = np.abs(p1[p1_nonzero])
    pm1 = np.abs(pm[p1_nonzero])
    p2  = np.abs(p2[p2_nonzero])
    pm2 = np.abs(pm[p2_nonzero])
    d = .5*( (p1*np.log(p1/pm1)).sum() + (p2*np.log(p2/pm2)).sum() )
    d /= np.log(2) # normalize to max of 1
    return d

# %%
data = np.load("/pscratch/sd/k/kberard/SCGSR/EDDA/BP/Data_Gen/NO_DFT/Synthetic_Transformed_N1000000_MD.npz")

# %%
print(data['x_train'].shape)
# Out:
# (1000, 140, 84, 112)

# %%
print(np.sum(x_train[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(np.sum(x_train[0]))
#
# NameError: name 'x_train' is not defined

# %%
x_train = data['x_train']
x_val   = data['x_val']
y_train = data['y_train']
y_val   = data['y_val']
n_samples = 10**6

x_train = x_train[..., np.newaxis]
x_val   = x_val[..., np.newaxis]

y_train = y_train[..., np.newaxis]
y_val   = y_val[..., np.newaxis]
data = 0

# %%
dft_path ='/pscratch/sd/k/kberard/SCGSR/Data/bp_1x1x1_ccecp/density_data/vmc_noJ/density_tot_ref.h5'
with h5py.File(dft_path, 'r') as file:
    dft_d = file['density'][:]
# 1. Get the residual map (what the network sees)
residual_map = x_train[0,:,:,:,0]
print(f"Residual Sum: {np.sum(residual_map):.2f} (Expected: close to 0, not 50)")

# 2. Inverse Transform to get Real Density
# Formula: Density = (Residual * sqrt(DFT)) + DFT
epsilon = 1e-9
dsqrt = np.sqrt(np.abs(dft_d) + epsilon)
restored_density = (residual_map * dsqrt) + dft_d

# 3. Check the Sum
total_electrons = np.sum(restored_density)
print(f"Total Electrons: {total_electrons:.4f} (Expected: ~8.0)")
# Out:
# Residual Sum: 331.47 (Expected: close to 0, not 50)
# Total Electrons: 21.1836 (Expected: ~8.0)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks

def create_residual_unet(input_shape):
    inputs = layers.Input(shape=input_shape)
    
    # Standard U-Net (Depth 2 is fine for residuals)
    # Encoder
    c1 = layers.Conv3D(32, 3, padding='same', activation='relu')(inputs)
    c1 = layers.Conv3D(32, 3, padding='same', activation='relu')(c1)
    p1 = layers.MaxPooling3D(2)(c1)
    
    c2 = layers.Conv3D(64, 3, padding='same', activation='relu')(p1)
    c2 = layers.Conv3D(64, 3, padding='same', activation='relu')(c2)
    p2 = layers.MaxPooling3D(2)(c2)
    
    # Bottleneck
    b = layers.Conv3D(128, 3, padding='same', activation='relu')(p2)
    b = layers.Conv3D(128, 3, padding='same', activation='relu')(b)
    
    # Decoder
    u1 = layers.UpSampling3D(2)(b)
    u1 = layers.Concatenate()([u1, c2])
    d1 = layers.Conv3D(64, 3, padding='same', activation='relu')(u1)
    d1 = layers.Conv3D(64, 3, padding='same', activation='relu')(d1)
    
    u2 = layers.UpSampling3D(2)(d1)
    u2 = layers.Concatenate()([u2, c1])
    d2 = layers.Conv3D(32, 3, padding='same', activation='relu')(u2)
    d2 = layers.Conv3D(32, 3, padding='same', activation='relu')(d2)
    
    # Output: predicting the RESIDUAL, can be negative, so LINEAR activation
    outputs = layers.Conv3D(1, 1, padding='same', activation='linear')(d2)
    
    return models.Model(inputs, outputs)

# Compile & Train
model = create_residual_unet(x_train.shape[1:])
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss='mse') 

model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    batch_size=8,
    epochs=50,
    callbacks=[
        callbacks.EarlyStopping(patience=10, restore_best_weights=True),
        callbacks.ReduceLROnPlateau(patience=5, factor=0.5)
    ]
)
model.save("residual_denoiser_40M_Blob_NODFT.keras")
# Out:
# I0000 00:00:1773105604.415070 1751300 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38479 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773105682.399844 1752997 service.cc:152] XLA service 0x7f0914213d00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1773105682.399879 1752997 service.cc:160]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2026-03-09 18:21:22.469350: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1773105682.883080 1752997 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2026-03-09 18:21:25.829362: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.34 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.4980, f32[32]{0} %bitcast.5039), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_1_2/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:21:26.693542: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.864292461s
# Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.34 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.4980, f32[32]{0} %bitcast.5039), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_1_2/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:21:33.268088: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.41 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.5723, f32[32]{0} %bitcast.5782), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_8_1/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:21:37.877937: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 5.60993782s
# Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.41 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.5723, f32[32]{0} %bitcast.5782), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_8_1/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:21:39.955832: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-09 18:21:40.133243: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-09 18:21:42.010223: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-input.9 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5891, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.5829), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_9_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:21:42.304876: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.294829072s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-input.9 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5891, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.5829), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_9_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:21:43.280033: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-09 18:21:43.518297: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-09 18:21:47.604809: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-input.10 = (f32[8,96,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.5723), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:21:50.381503: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 3.776775283s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-input.10 = (f32[8,96,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.5723), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:21:53.918377: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-input.12 = (f32[8,192,70,42,56]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5575, f32[64,192,3,3,3]{4,3,2,1,0} %bitcast.5512), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_6_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:21:54.799430: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.881136664s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-input.12 = (f32[8,192,70,42,56]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5575, f32[64,192,3,3,3]{4,3,2,1,0} %bitcast.5512), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv3DBackpropInputV2" op_name="gradient_tape/functional_1/conv3d_6_1/convolution/Conv3DBackpropInputV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773105716.964960 1752997 buffer_comparator.cc:156] Difference at 0: 2.57398e+06, expected 2.27203e+06
# E0000 00:00:1773105716.964991 1752997 buffer_comparator.cc:156] Difference at 1: 2.59876e+06, expected 2.29023e+06
# E0000 00:00:1773105716.964995 1752997 buffer_comparator.cc:156] Difference at 2: 2.57287e+06, expected 2.27012e+06
# E0000 00:00:1773105716.964997 1752997 buffer_comparator.cc:156] Difference at 3: 2.60688e+06, expected 2.29506e+06
# E0000 00:00:1773105716.965000 1752997 buffer_comparator.cc:156] Difference at 4: 2.62667e+06, expected 2.31083e+06
# E0000 00:00:1773105716.965003 1752997 buffer_comparator.cc:156] Difference at 5: 2.61028e+06, expected 2.29907e+06
# E0000 00:00:1773105716.965005 1752997 buffer_comparator.cc:156] Difference at 6: 2.57966e+06, expected 2.27717e+06
# E0000 00:00:1773105716.965008 1752997 buffer_comparator.cc:156] Difference at 7: 2.60117e+06, expected 2.29246e+06
# E0000 00:00:1773105716.965010 1752997 buffer_comparator.cc:156] Difference at 8: 2.56918e+06, expected 2.2692e+06
# E0000 00:00:1773105716.965013 1752997 buffer_comparator.cc:156] Difference at 9: 2.59744e+06, expected 2.28985e+06
# 2026-03-09 18:21:56.965024: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.11 = (f32[32,1,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.4520, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4937), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=0,k12=54,k13=2,k14=3,k15=1,k17=55,k18=1,k23=0} vs eng23{k2=8,k13=1,k14=4,k18=1,k23=0}
# 2026-03-09 18:21:56.965036: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-09 18:21:56.965039: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-09 18:21:56.965042: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-09 18:21:56.965044: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-09 18:21:56.965048: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# E0000 00:00:1773105717.636541 1752997 buffer_comparator.cc:156] Difference at 0: 2.57398e+06, expected 2.27203e+06
# E0000 00:00:1773105717.636561 1752997 buffer_comparator.cc:156] Difference at 1: 2.59876e+06, expected 2.29023e+06
# E0000 00:00:1773105717.636565 1752997 buffer_comparator.cc:156] Difference at 2: 2.57287e+06, expected 2.27012e+06
# E0000 00:00:1773105717.636567 1752997 buffer_comparator.cc:156] Difference at 3: 2.60688e+06, expected 2.29506e+06
# E0000 00:00:1773105717.636570 1752997 buffer_comparator.cc:156] Difference at 4: 2.62667e+06, expected 2.31083e+06
# E0000 00:00:1773105717.636573 1752997 buffer_comparator.cc:156] Difference at 5: 2.61028e+06, expected 2.29907e+06
# E0000 00:00:1773105717.636575 1752997 buffer_comparator.cc:156] Difference at 6: 2.57966e+06, expected 2.27717e+06
# E0000 00:00:1773105717.636578 1752997 buffer_comparator.cc:156] Difference at 7: 2.60117e+06, expected 2.29246e+06
# E0000 00:00:1773105717.636580 1752997 buffer_comparator.cc:156] Difference at 8: 2.56918e+06, expected 2.2692e+06
# E0000 00:00:1773105717.636583 1752997 buffer_comparator.cc:156] Difference at 9: 2.59744e+06, expected 2.28985e+06
# 2026-03-09 18:21:57.636593: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.11 = (f32[32,1,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.4520, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4937), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=0,k12=54,k13=2,k14=3,k15=1,k17=55,k18=1,k23=0} vs eng23{k2=5,k13=1,k14=3,k18=1,k23=0}
# 2026-03-09 18:21:57.636600: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-09 18:21:57.636602: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-09 18:21:57.636605: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-09 18:21:57.636607: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-09 18:21:57.636611: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-09 18:22:00.901330: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.11 = (f32[32,1,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.4520, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4937), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773105722.349327 1752997 buffer_comparator.cc:156] Difference at 0: 2.57398e+06, expected 2.27203e+06
# E0000 00:00:1773105722.349366 1752997 buffer_comparator.cc:156] Difference at 1: 2.59876e+06, expected 2.29023e+06
# E0000 00:00:1773105722.349371 1752997 buffer_comparator.cc:156] Difference at 2: 2.57287e+06, expected 2.27012e+06
# E0000 00:00:1773105722.349374 1752997 buffer_comparator.cc:156] Difference at 3: 2.60688e+06, expected 2.29506e+06
# E0000 00:00:1773105722.349377 1752997 buffer_comparator.cc:156] Difference at 4: 2.62667e+06, expected 2.31083e+06
# E0000 00:00:1773105722.349380 1752997 buffer_comparator.cc:156] Difference at 5: 2.61028e+06, expected 2.29907e+06
# E0000 00:00:1773105722.349383 1752997 buffer_comparator.cc:156] Difference at 6: 2.57966e+06, expected 2.27717e+06
# E0000 00:00:1773105722.349386 1752997 buffer_comparator.cc:156] Difference at 7: 2.60117e+06, expected 2.29246e+06
# E0000 00:00:1773105722.349389 1752997 buffer_comparator.cc:156] Difference at 8: 2.56918e+06, expected 2.2692e+06
# E0000 00:00:1773105722.349392 1752997 buffer_comparator.cc:156] Difference at 9: 2.59744e+06, expected 2.28985e+06
# 2026-03-09 18:22:02.349405: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.11 = (f32[32,1,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.4520, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4937), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=0,k12=54,k13=2,k14=3,k15=1,k17=55,k18=1,k23=0} vs eng23{k2=6,k13=0,k14=2,k18=1,k23=0}
# 2026-03-09 18:22:02.349416: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-09 18:22:02.349419: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-09 18:22:02.349422: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-09 18:22:02.349425: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-09 18:22:02.349429: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-09 18:22:02.349438: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.448225051s
# Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.11 = (f32[32,1,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.4520, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4937), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773105723.284615 1752997 buffer_comparator.cc:156] Difference at 0: 2.53402e+06, expected 2.27141e+06
# E0000 00:00:1773105723.284632 1752997 buffer_comparator.cc:156] Difference at 1: 2.56405e+06, expected 2.29326e+06
# E0000 00:00:1773105723.284636 1752997 buffer_comparator.cc:156] Difference at 2: 2.53728e+06, expected 2.27383e+06
# E0000 00:00:1773105723.284638 1752997 buffer_comparator.cc:156] Difference at 3: 2.57423e+06, expected 2.30145e+06
# E0000 00:00:1773105723.284641 1752997 buffer_comparator.cc:156] Difference at 4: 2.58744e+06, expected 2.31134e+06
# E0000 00:00:1773105723.284644 1752997 buffer_comparator.cc:156] Difference at 5: 2.57304e+06, expected 2.29988e+06
# E0000 00:00:1773105723.284646 1752997 buffer_comparator.cc:156] Difference at 6: 2.54073e+06, expected 2.2749e+06
# E0000 00:00:1773105723.284649 1752997 buffer_comparator.cc:156] Difference at 7: 2.54695e+06, expected 2.28108e+06
# E0000 00:00:1773105723.284653 1752997 buffer_comparator.cc:156] Difference at 8: 2.52413e+06, expected 2.26228e+06
# E0000 00:00:1773105723.284655 1752997 buffer_comparator.cc:156] Difference at 9: 2.559e+06, expected 2.29096e+06
# 2026-03-09 18:22:03.284665: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=7,k12=7,k13=0,k14=4,k15=1,k17=8,k18=1,k23=0} vs eng23{k2=8,k13=1,k14=4,k18=1,k23=0}
# 2026-03-09 18:22:03.284673: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-09 18:22:03.284676: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-09 18:22:03.284678: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-09 18:22:03.284680: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-09 18:22:03.284684: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# E0000 00:00:1773105723.763541 1752997 buffer_comparator.cc:156] Difference at 0: 2.53402e+06, expected 2.27141e+06
# E0000 00:00:1773105723.763555 1752997 buffer_comparator.cc:156] Difference at 1: 2.56405e+06, expected 2.29326e+06
# E0000 00:00:1773105723.763559 1752997 buffer_comparator.cc:156] Difference at 2: 2.53728e+06, expected 2.27383e+06
# E0000 00:00:1773105723.763562 1752997 buffer_comparator.cc:156] Difference at 3: 2.57423e+06, expected 2.30145e+06
# E0000 00:00:1773105723.763565 1752997 buffer_comparator.cc:156] Difference at 4: 2.58744e+06, expected 2.31134e+06
# E0000 00:00:1773105723.763568 1752997 buffer_comparator.cc:156] Difference at 5: 2.57304e+06, expected 2.29988e+06
# E0000 00:00:1773105723.763571 1752997 buffer_comparator.cc:156] Difference at 6: 2.54073e+06, expected 2.2749e+06
# E0000 00:00:1773105723.763574 1752997 buffer_comparator.cc:156] Difference at 7: 2.54695e+06, expected 2.28108e+06
# E0000 00:00:1773105723.763577 1752997 buffer_comparator.cc:156] Difference at 8: 2.52413e+06, expected 2.26228e+06
# E0000 00:00:1773105723.763580 1752997 buffer_comparator.cc:156] Difference at 9: 2.559e+06, expected 2.29096e+06
# 2026-03-09 18:22:03.763591: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=7,k12=7,k13=0,k14=4,k15=1,k17=8,k18=1,k23=0} vs eng23{k2=5,k13=1,k14=3,k18=1,k23=0}
# 2026-03-09 18:22:03.763599: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-09 18:22:03.763602: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-09 18:22:03.763605: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-09 18:22:03.763607: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-09 18:22:03.763611: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-09 18:22:06.226843: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng20{k2=3,k3=0} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:06.387632: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.160884083s
# Trying algorithm eng20{k2=3,k3=0} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:07.387790: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773105728.460165 1752997 buffer_comparator.cc:156] Difference at 0: 2.53402e+06, expected 2.27141e+06
# E0000 00:00:1773105728.460193 1752997 buffer_comparator.cc:156] Difference at 1: 2.56405e+06, expected 2.29326e+06
# E0000 00:00:1773105728.460197 1752997 buffer_comparator.cc:156] Difference at 2: 2.53728e+06, expected 2.27383e+06
# E0000 00:00:1773105728.460200 1752997 buffer_comparator.cc:156] Difference at 3: 2.57423e+06, expected 2.30145e+06
# E0000 00:00:1773105728.460203 1752997 buffer_comparator.cc:156] Difference at 4: 2.58744e+06, expected 2.31134e+06
# E0000 00:00:1773105728.460206 1752997 buffer_comparator.cc:156] Difference at 5: 2.57304e+06, expected 2.29988e+06
# E0000 00:00:1773105728.460209 1752997 buffer_comparator.cc:156] Difference at 6: 2.54073e+06, expected 2.2749e+06
# E0000 00:00:1773105728.460212 1752997 buffer_comparator.cc:156] Difference at 7: 2.54695e+06, expected 2.28108e+06
# E0000 00:00:1773105728.460215 1752997 buffer_comparator.cc:156] Difference at 8: 2.52413e+06, expected 2.26228e+06
# E0000 00:00:1773105728.460218 1752997 buffer_comparator.cc:156] Difference at 9: 2.559e+06, expected 2.29096e+06
# 2026-03-09 18:22:08.460231: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng30{k2=7,k12=7,k13=0,k14=4,k15=1,k17=8,k18=1,k23=0} vs eng23{k2=6,k13=0,k14=2,k18=1,k23=0}
# 2026-03-09 18:22:08.460240: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-09 18:22:08.460243: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-09 18:22:08.460246: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-09 18:22:08.460249: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-09 18:22:08.460253: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-09 18:22:08.460261: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.072582535s
# Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:09.460378: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:11.469102: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 3.0087998s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.12 = (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.4989, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5043), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_1_2/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:15.415885: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.14 = (f32[64,64,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5202, f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5256), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_3_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:15.840941: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.425164711s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.14 = (f32[64,64,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5202, f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5256), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_3_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:20.468777: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.17 = (f32[64,192,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,192,70,42,56]{4,3,2,1,0} %bitcast.5521, f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5575), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_6_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:23.715248: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 4.246553179s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.17 = (f32[64,192,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,192,70,42,56]{4,3,2,1,0} %bitcast.5521, f32[8,64,70,42,56]{4,3,2,1,0} %bitcast.5575), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_6_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:27.338015: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng20{k2=7,k3=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:27.404437: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.066530846s
# Trying algorithm eng20{k2=7,k3=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:29.268682: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng20{k2=3,k3=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:30.367405: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.098802372s
# Trying algorithm eng20{k2=3,k3=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:31.367539: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:32.452916: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.085459959s
# Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:33.453065: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:22:41.184093: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 8.73112643s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.19 = (f32[32,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.5732, f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5786), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_8_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773105762.972987 1752997 buffer_comparator.cc:156] Difference at 0: 2.65755e+06, expected 2.3267e+06
# E0000 00:00:1773105762.973022 1752997 buffer_comparator.cc:156] Difference at 1: 2.6595e+06, expected 2.33052e+06
# E0000 00:00:1773105762.973026 1752997 buffer_comparator.cc:156] Difference at 2: 2.65214e+06, expected 2.32367e+06
# E0000 00:00:1773105762.973029 1752997 buffer_comparator.cc:156] Difference at 3: 2.6581e+06, expected 2.32852e+06
# E0000 00:00:1773105762.973032 1752997 buffer_comparator.cc:156] Difference at 4: 2.65554e+06, expected 2.32582e+06
# ...
# 2026-03-09 18:22:46.780587: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-09 18:22:46.780589: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-09 18:22:46.780592: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-09 18:22:46.780595: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-09 18:22:46.780598: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-09 18:22:47.780745: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.21 = (f32[1,32,1,1,1]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5940, f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.5942), window={size=1x1x1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_10_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# E0000 00:00:1773105768.848765 1752997 buffer_comparator.cc:156] Difference at 0: 2.65755e+06, expected 2.3267e+06
# E0000 00:00:1773105768.848788 1752997 buffer_comparator.cc:156] Difference at 1: 2.6595e+06, expected 2.33052e+06
# E0000 00:00:1773105768.848791 1752997 buffer_comparator.cc:156] Difference at 2: 2.65214e+06, expected 2.32367e+06
# E0000 00:00:1773105768.848794 1752997 buffer_comparator.cc:156] Difference at 3: 2.6581e+06, expected 2.32852e+06
# E0000 00:00:1773105768.848796 1752997 buffer_comparator.cc:156] Difference at 4: 2.65554e+06, expected 2.32582e+06
# E0000 00:00:1773105768.848799 1752997 buffer_comparator.cc:156] Difference at 5: 2.65227e+06, expected 2.32594e+06
# E0000 00:00:1773105768.848802 1752997 buffer_comparator.cc:156] Difference at 6: 2.65491e+06, expected 2.32607e+06
# E0000 00:00:1773105768.848804 1752997 buffer_comparator.cc:156] Difference at 7: 2.65529e+06, expected 2.32726e+06
# E0000 00:00:1773105768.848807 1752997 buffer_comparator.cc:156] Difference at 8: 2.65657e+06, expected 2.32894e+06
# E0000 00:00:1773105768.848810 1752997 buffer_comparator.cc:156] Difference at 9: 2.65861e+06, expected 2.32897e+06
# 2026-03-09 18:22:48.848820: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:764] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# %cudnn-conv-bw-filter.21 = (f32[1,32,1,1,1]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5940, f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.5942), window={size=1x1x1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_10_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} for eng62{k25=2} vs eng23{k2=6,k13=0,k14=2,k18=1,k23=0}
# 2026-03-09 18:22:48.848830: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:323] Device: NVIDIA A100-SXM4-40GB
# 2026-03-09 18:22:48.848832: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:324] Platform: Compute Capability 8.0
# 2026-03-09 18:22:48.848835: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:325] Driver: 13.0.0
# 2026-03-09 18:22:48.848837: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:326] Runtime: 12.9.0
# 2026-03-09 18:22:48.848842: E external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:331] cudnn version: 9.3.0
# 2026-03-09 18:22:48.848849: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.068222064s
# Trying algorithm eng23{k2=6,k13=0,k14=2,k18=1,k23=0} for conv %cudnn-conv-bw-filter.21 = (f32[1,32,1,1,1]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.5940, f32[8,1,140,84,112]{4,3,2,1,0} %bitcast.5942), window={size=1x1x1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv3DBackpropFilterV2" op_name="gradient_tape/functional_1/conv3d_10_1/convolution/Conv3DBackpropFilterV2" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# I0000 00:00:1773105783.261857 1752997 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - loss: 6.1076e-08
# 2026-03-09 18:23:55.212951: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.34 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.498, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.505, f32[32]{0} %bitcast.507), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_1_2/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:23:56.077434: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.864575715s
# Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.34 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,140,84,112]{4,3,2,1,0} %bitcast.498, f32[32,32,3,3,3]{4,3,2,1,0} %bitcast.505, f32[32]{0} %bitcast.507), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_1_2/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:24:02.647485: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.41 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.619, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.626, f32[32]{0} %bitcast.628), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_8_1/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-03-09 18:24:07.257789: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 5.610392624s
# Trying algorithm eng0{} for conv %cudnn-conv-bias-activation.41 = (f32[8,32,140,84,112]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,140,84,112]{4,3,2,1,0} %bitcast.619, f32[32,96,3,3,3]{4,3,2,1,0} %bitcast.626, f32[32]{0} %bitcast.628), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv3D" op_name="functional_1/conv3d_8_1/convolution" source_file="/global/u2/k/kberard/environments/SCGSR/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 170s 536ms/step - loss: 6.0972e-08 - val_loss: 3.9542e-08 - learning_rate: 1.0000e-04
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 403ms/step - loss: 3.8066e-08 - val_loss: 3.5450e-08 - learning_rate: 1.0000e-04
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 3.3723e-08 - val_loss: 3.0073e-08 - learning_rate: 1.0000e-04
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 403ms/step - loss: 2.9867e-08 - val_loss: 2.8845e-08 - learning_rate: 1.0000e-04
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 2.7723e-08 - val_loss: 2.5130e-08 - learning_rate: 1.0000e-04
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 404ms/step - loss: 2.7269e-08 - val_loss: 2.4200e-08 - learning_rate: 1.0000e-04
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 2.3100e-08 - val_loss: 2.1041e-08 - learning_rate: 5.0000e-05
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 2.0211e-08 - val_loss: 1.9815e-08 - learning_rate: 5.0000e-05
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 403ms/step - loss: 2.0124e-08 - val_loss: 1.8663e-08 - learning_rate: 5.0000e-05
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.8934e-08 - val_loss: 1.7542e-08 - learning_rate: 5.0000e-05
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 403ms/step - loss: 1.9125e-08 - val_loss: 1.6739e-08 - learning_rate: 5.0000e-05
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.6483e-08 - val_loss: 1.5669e-08 - learning_rate: 2.5000e-05
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.5771e-08 - val_loss: 1.5138e-08 - learning_rate: 2.5000e-05
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.5220e-08 - val_loss: 1.4701e-08 - learning_rate: 2.5000e-05
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.4715e-08 - val_loss: 1.4026e-08 - learning_rate: 2.5000e-05
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.3892e-08 - val_loss: 1.3557e-08 - learning_rate: 2.5000e-05
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.3646e-08 - val_loss: 1.3274e-08 - learning_rate: 1.2500e-05
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.3309e-08 - val_loss: 1.3019e-08 - learning_rate: 1.2500e-05
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.3116e-08 - val_loss: 1.2810e-08 - learning_rate: 1.2500e-05
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 404ms/step - loss: 1.2824e-08 - val_loss: 1.2575e-08 - learning_rate: 1.2500e-05
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 403ms/step - loss: 1.2660e-08 - val_loss: 1.2354e-08 - learning_rate: 1.2500e-05
# Epoch 22/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 404ms/step - loss: 1.2614e-08 - val_loss: 1.2252e-08 - learning_rate: 6.2500e-06
# Epoch 23/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 403ms/step - loss: 1.2276e-08 - val_loss: 1.2148e-08 - learning_rate: 6.2500e-06
# Epoch 24/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 1.2093e-08 - val_loss: 1.2068e-08 - learning_rate: 6.2500e-06
# Epoch 25/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.2008e-08 - val_loss: 1.1956e-08 - learning_rate: 6.2500e-06
# Epoch 26/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.2013e-08 - val_loss: 1.1875e-08 - learning_rate: 6.2500e-06
# Epoch 27/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1930e-08 - val_loss: 1.1813e-08 - learning_rate: 3.1250e-06
# Epoch 28/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1878e-08 - val_loss: 1.1763e-08 - learning_rate: 3.1250e-06
# Epoch 29/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1929e-08 - val_loss: 1.1715e-08 - learning_rate: 3.1250e-06
# Epoch 30/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1840e-08 - val_loss: 1.1670e-08 - learning_rate: 3.1250e-06
# Epoch 31/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1598e-08 - val_loss: 1.1617e-08 - learning_rate: 3.1250e-06
# Epoch 32/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 404ms/step - loss: 1.1747e-08 - val_loss: 1.1592e-08 - learning_rate: 1.5625e-06
# Epoch 33/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1647e-08 - val_loss: 1.1572e-08 - learning_rate: 1.5625e-06
# Epoch 34/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1460e-08 - val_loss: 1.1548e-08 - learning_rate: 1.5625e-06
# Epoch 35/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1549e-08 - val_loss: 1.1529e-08 - learning_rate: 1.5625e-06
# Epoch 36/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1509e-08 - val_loss: 1.1501e-08 - learning_rate: 1.5625e-06
# Epoch 37/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - loss: 1.1786e-08 - val_loss: 1.1490e-08 - learning_rate: 7.8125e-07
# Epoch 38/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1549e-08 - val_loss: 1.1475e-08 - learning_rate: 7.8125e-07
# Epoch 39/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 404ms/step - loss: 1.1509e-08 - val_loss: 1.1466e-08 - learning_rate: 7.8125e-07
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1632e-08 - val_loss: 1.1447e-08 - learning_rate: 7.8125e-07
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 404ms/step - loss: 1.1630e-08 - val_loss: 1.1453e-08 - learning_rate: 7.8125e-07
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1466e-08 - val_loss: 1.1428e-08 - learning_rate: 3.9062e-07
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 404ms/step - loss: 1.1474e-08 - val_loss: 1.1427e-08 - learning_rate: 3.9062e-07
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1310e-08 - val_loss: 1.1416e-08 - learning_rate: 3.9062e-07
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 403ms/step - loss: 1.1520e-08 - val_loss: 1.1414e-08 - learning_rate: 3.9062e-07
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1541e-08 - val_loss: 1.1402e-08 - learning_rate: 3.9062e-07
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1518e-08 - val_loss: 1.1399e-08 - learning_rate: 1.9531e-07
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 50s 403ms/step - loss: 1.1383e-08 - val_loss: 1.1401e-08 - learning_rate: 1.9531e-07
# Epoch 49/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1456e-08 - val_loss: 1.1399e-08 - learning_rate: 1.9531e-07
# Epoch 50/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 51s 403ms/step - loss: 1.1576e-08 - val_loss: 1.1391e-08 - learning_rate: 1.9531e-07

# %%
with h5py.File('/pscratch/sd/k/kberard/SCGSR/Data/bp_1x1x1_ccecp/density_data/vmc_J2/density_tot_ref_mean.h5', 'r') as file:
    #print("Keys: %s" % file.keys())
    test_d = file['density'][:]

# %%
#Transform density
def transform(density,density_ref,transform_type):
    dens = density
    dref  = density_ref
    ttype = transform_type
    if ttype=='value':
        dtrans = density
    elif ttype=='sqrt':
        dtrans = np.sqrt(np.abs(density))
    elif ttype=='log':
        dtrans  = np.log(np.abs(density))
    elif ttype=='residual_noise':
        dval  = dref
        dsqrt = np.sqrt(np.abs(dref))
        dtrans = (dens-dval)/dsqrt
    else:
        raise RuntimeError('bad transform type')
    return dtrans


def inverse_transform(density_trans,density_ref,transform_type):
    dref   = density_ref
    ttype  = transform_type
    dtrans = density_trans
    if ttype=='value':
        density = dtrans
    elif ttype=='sqrt':
        density = dtrans**2
    elif ttype=='log':
        density = np.log(np.abs(dtrans))
    elif ttype=='residual_noise':
        dval  = dref
        dsqrt = np.sqrt(np.abs(dref))
        density = dval + dsqrt*dtrans
    else:
        raise RuntimeError('bad transform type')
    return density

# %%
import os
import glob
import h5py
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import re
dft_path ='/pscratch/sd/k/kberard/SCGSR/Data/bp_1x1x1_ccecp/density_data/vmc_noJ/density_tot_ref.h5'
with h5py.File(dft_path, 'r') as file:
    dft_d = file['density'][:]

# %%
import numpy as np
import matplotlib.pyplot as plt
model = tf.keras.models.load_model('residual_denoiser_40M_Blob_NODFT.keras')

ref_path ='/pscratch/sd/k/kberard/SCGSR/Data/bp_1x1x1_ccecp/density_data/vmc_J2/density_tot_ref_mean.h5'
with h5py.File(ref_path, 'r') as file:
    ref_d = file['density'][:]
# -----------------------------------------------------------
# 1. PREPARE DATA FOR MODEL
# -----------------------------------------------------------
# Reshape arrays to (1, H, W, D, 1) for the model
# We need 'dft_d' because the residual transform relies on it.
input_reshaped = test_d[np.newaxis, ..., np.newaxis]
dft_reshaped   = dft_d[np.newaxis, ..., np.newaxis]

# -----------------------------------------------------------
# 2. TRANSFORM INPUT (Forward Pass)
# -----------------------------------------------------------
# Convert raw noisy density -> "How far is this from DFT?"
# Uses the 'transform' function we defined earlier
input_residual = transform(input_reshaped, dft_reshaped, 'residual_noise')

# -----------------------------------------------------------
# 3. PREDICT
# -----------------------------------------------------------
# The model predicts the "Corrected Residual"
pred_residual = model.predict(input_residual)

# -----------------------------------------------------------
# 4. INVERSE TRANSFORM (Recover Density)
# -----------------------------------------------------------
# Convert "Corrected Residual" back to "Physical Density"
# Logic: Density = DFT + (Residual * sqrt(DFT))
denoised_raw = inverse_transform(pred_residual, dft_reshaped, 'residual_noise')

# Squeeze back to 3D shape (116, 116, 72)
denoised = denoised_raw[0, ..., 0]

# Safety: Density cannot be negative (physics constraint)
denoised = np.maximum(denoised, 0.0)

# -----------------------------------------------------------
# 5. VISUALIZATION & METRICS (Your snippet)
# -----------------------------------------------------------
noisy_input = test_d
true_clean = ref_d

# Dynamic z-slice (don't hardcode 64 if depth is 72)
z_mid = noisy_input.shape[2] // 2

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(noisy_input[:, :, z_mid], cmap='viridis')
plt.title("Noisy Input")
plt.colorbar()

plt.subplot(1, 3, 2)
plt.imshow(denoised[:, :, z_mid], cmap='viridis')
plt.title("Denoised Output\n(Residual Reconstructed)")
plt.colorbar()

plt.subplot(1, 3, 3)
plt.imshow(true_clean[:, :, z_mid], cmap='viridis')
plt.title("Reference (Ground Truth)")
plt.colorbar()

plt.tight_layout()
plt.show()

# Metric Calculation
# Ensure JSD handles small epsilons
print("JSD between noisy and Ref:", D_JS(test_d, ref_d, tol=1e-16))
print("JSD between denoised and Ref:", D_JS(denoised, ref_d, tol=1e-16))
print("JSD between denoised and DFT:", D_JS(denoised, dft_d, tol=1e-16))
print("JSD between noise and DFT:", D_JS(test_d, dft_d, tol=1e-16))
print("JSD between Ref and DFT:", D_JS(ref_d, dft_d, tol=1e-16))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# JSD between noisy and Ref: 0.0
# JSD between denoised and Ref: 6.307982104935364e-05
# JSD between denoised and DFT: 0.0002704281166592582
# JSD between noise and DFT: 0.00018184807341338878
# JSD between Ref and DFT: 0.00018184807341338878

# %%
print("here")
# Out:
# here

# %%
# --- Setup Directory Looping ---
model = tf.keras.models.load_model('residual_denoiser_40M_Blob_NODFT.keras')
data_dir = '/pscratch/sd/k/kberard/SCGSR/Data/bp_1x1x1_ccecp/density_data/vmc_J2/'
file_pattern = os.path.join(data_dir, "density_tot_vmc_mean_*.h5")
files = glob.glob(file_pattern)

results = []

# --- Processing Loop ---
for fpath in files:
    # Extract number of samples from filename using regex
    match = re.search(r'mean_(\d+)\.h5', os.path.basename(fpath))
    if not match: continue
    sample_count = int(match.group(1))
    
    with h5py.File(fpath, 'r') as f:
        test_d = np.array(f['density'])
    
    # 1. Transform & Predict
    input_reshaped = test_d[np.newaxis, ..., np.newaxis]
    dft_reshaped   = dft_d[np.newaxis, ..., np.newaxis]
    input_residual = transform(input_reshaped, dft_reshaped, 'residual_noise')
    
    pred_residual = model.predict(input_residual, verbose=0)
    
    # 2. Inverse Transform
    denoised_raw = inverse_transform(pred_residual, dft_reshaped, 'residual_noise')
    denoised = np.maximum(denoised_raw[0, ..., 0], 0.0)

    # 3. Store Metrics
    jsd_noisy = D_JS(test_d, ref_d)
    jsd_denoised = D_JS(denoised, ref_d)
    
    results.append((sample_count, jsd_noisy, jsd_denoised))

# --- Sorting & Plotting ---
# Sort results by sample count (x-axis)
results.sort(key=lambda x: x[0])
samples, noisy_jsds, denoised_jsds = zip(*results)

# %%
DFT_vs_DMC = D_JS(ref_d,dft_d)
plt.figure(figsize=(10, 6))
plt.plot(samples, noisy_jsds, 'r--o', label='Noisy vs Reference', alpha=0.6)
plt.plot(samples, denoised_jsds, 'g-s', label='Denoised vs Reference', linewidth=2)

plt.xscale('log') # Sample counts usually span orders of magnitude
plt.yscale('log') # JSD values often drop significantly
plt.axhline(DFT_vs_DMC, color="black", linestyle=":", label="DFT vs DMC")
plt.xlabel('Number of Samples (VMC)')
plt.ylabel('$D_{JS}$ (Jensen-Shannon Divergence)')
plt.title('Denoising Error Reduction vs. Sample Count')
plt.legend()
plt.grid(True, which="both", ls="-", alpha=0.2)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Create a DataFrame with your data
data = {
    'Samples': samples,
    'Noisy_JSD': noisy_jsds,
    'Denoised_JSD': denoised_jsds
}
df = pd.DataFrame(data)

# Save to CSV
df.to_csv('bp_jsd_data.csv', index=False)
print("Data saved to bp_jsd_data.csv")
# Out:
# Data saved to bp_jsd_data.csv
